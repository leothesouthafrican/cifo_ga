# %%
#Importing libraries
import pandas as pd
import os

# %%
#Import different dfs

def single_alg_dataframe_importer(path):

    list_of_dfs = []
    for i in os.listdir(path):
        if i != ".DS_Store":
            temp_df = pd.read_excel(path + i)
            temp_df = temp_df.iloc[0:199,1:-1]
            list_of_dfs.append(temp_df)
    
    return list_of_dfs




single_alg_dataframe_importer("./results/spec_1/")[0]
# Out:
#      Unnamed: 0  best_fitness  \
# 0             0        2450.0
# 1             1        2450.0
# 2             2        2450.0
# 3             3        2450.0
# 4             4        2450.0
# ..          ...           ...
# 194         194        2600.0
# 195         195        2600.0
# 196         196        2600.0
# 197         197        2600.0
# 198         198        2600.0
#
#                            best_fitness_representation  best_fit_length  \
# 0    [-0.407, -0.208, -0.156, -0.571, -0.043, 0.031...              3.0
# 1    [-0.887, 0.913, -0.403, -0.595, 0.164, -0.465,...              3.0
# 2    [-0.8353822482597213, -0.944363939074212, 0.85...              3.0
# 3    [-0.8353822482597213, -0.944363939074212, 0.85...              3.0
# 4    [-0.312, -0.036, 0.199, 0.378, 0.307, -0.237, ...              3.0
# ..                                                 ...              ...
# 194  [0.7308265300033827, 0.40056161228229725, 0.52...              4.0
# 195  [0.7308265300033827, 0.40056161228229725, 0.52...              4.0
# 196  [0.7308265300033827, 0.40056161228229725, 0.52...              4.0
# 197  [0.7308265300033827, 0.40056161228229725, 0.52...              4.0
# 198  [0.7308265300033827, 0.40056161228229725, 0.52...              4.0
#
#      best_fit_steps  average_fitness  phenotypic_variance  genotypic_variance  \
# 0            2000.0      1538.226667             974631.0             3.51239
# 1            2000.0      1487.080000             977008.0             8.26268
# 2            2000.0      1614.173333             923503.0             3.72723
# 3            2000.0      1450.080000             992185.0             4.26947
# 4            2000.0      1483.026667             993571.0             3.55785
# ..              ...              ...                  ...                 ...
# 194          2000.0      1572.680000             968394.0             0.66860
# 195          2000.0      1584.960000             938596.0             0.50595
# 196          2000.0      1327.240000            1027572.0             0.21063
# 197          2000.0      1677.160000             894389.0             0.79821
# 198          2000.0      1405.040000            1005099.0             0.38118
#
#            time
# 0      5.269349
# 1      7.792265
# 2     10.607546
# 3     13.071287
# 4     15.617349
# ..          ...
# 194  524.894123
# 195  527.661069
# 196  529.844014
# 197  532.784451
# 198  535.138280
#
# [199 rows x 9 columns]
